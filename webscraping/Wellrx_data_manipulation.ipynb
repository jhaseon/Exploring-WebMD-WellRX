# %%
# Import necessary files 
import pandas as pd

# %%
df = pd.read_csv('Wellrx_Selenium.csv')
df.head()

# %%
# Clean data
df['price'] = df['price'].str.extract('(\d+\.\d+)')
df['price1'] = df['price1'].str.extract('(\d+\.\d+)')

# %%
# Take a look at the columns
for col in df.columns: 
    print(col)

# %%
# Look at results
df.head()

# %%
# Export to csv
df.to_csv('Wellrx_final.csv', index = False )
